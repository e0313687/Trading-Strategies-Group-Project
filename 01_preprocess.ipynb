# %% [markdown]
# # Preprocess

# %% [markdown]
# # Setup

# %% [markdown]
# ## Install library

# %%
# !pip install xlrd
# !pip install openpyxl
# !pip install yfinance

# %% [markdown]
# ## Import library

# %%
# System
import random
import os
import shutil
import time
import datetime as dt

# Network
import requests

# Data Structure
import pandas as pd

# Data source
import yfinance as yf

# User defined
import constants

# %% [markdown]
# ## Define parameter

# %% [markdown]
# Retrieve from *constants.py*

# %%
# Trading days
start_date = constants.start_date
end_date = constants.end_date

# Directory
data_dir_url = constants.data_dir_url

# CSV file list
csv_file_list = [
                    constants.inst_buy_file, constants.inst_sell_file, 
                    constants.retail_buy_file, constants.retail_sell_file
                ]

# %% [markdown]
# Get every Monday with the given range

# %%
trading_date_list = pd.date_range(start=start_date, end=end_date, freq='W-MON')
trading_date_list
# Out:
# DatetimeIndex(['2019-01-07', '2019-01-14', '2019-01-21', '2019-01-28',
#                '2019-02-04', '2019-02-11', '2019-02-18', '2019-02-25',
#                '2019-03-04', '2019-03-11',
#                ...
#                '2022-08-29', '2022-09-05', '2022-09-12', '2022-09-19',
#                '2022-09-26', '2022-10-03', '2022-10-10', '2022-10-17',
#                '2022-10-24', '2022-10-31'],
#               dtype='datetime64[ns]', length=200, freq='W-MON')

# %% [markdown]
# # Fetch data

# %%
def parse_excel(excel_res, inst_header=4, retail_header=17):
    inst_data = pd.read_excel(excel_res, header=inst_header, nrows=10)
    retail_data = pd.read_excel(excel_res, header=retail_header, nrows=10)

    inst_buy = inst_data.iloc[:, :3]
    inst_sell = inst_data.iloc[:, 3:6]

    retail_buy = retail_data.iloc[:, :3]
    retail_sell = retail_data.iloc[:, 3:6]

    return inst_buy, inst_sell, retail_buy, retail_sell

# %%
def write_csv(df: pd.DataFrame, file_path: str, published_date: dt):
    # standardise the column name
    df.columns = ['stock', 'stock code', 'net amount (S$M)']

    # standised to yfinance stock code format
    df['stock code'] = df['stock code'].apply(lambda ticker: str(ticker) + '.SI')

    # add date
    df['published date'] = published_date.strftime('%Y-%m-%d')

    # if file not exist then add the header
    is_file_exist = not os.path.exists(file_path)
    df.to_csv(file_path, index=False, mode='a', header=is_file_exist)

# %%
file_has_postfix = {
    '2019-02-11': '_3',
    '2019-04-01': '_0',
    '2019-04-15': '_0',
    '2019-06-10': '_0',
    '2019-06-24': '_0',
    '2019-09-16': '_2',
    '2019-10-28': '_0',
    '2019-11-25': '_0',
    '2019-12-09': '_0',
    '2019-12-16': '_0',
    '2020-02-24': '_2',
    '2020-04-27': '_0',
    '2020-05-11': '_0',
    '2020-11-23': '_0',
    '2020-11-30': '_0',
    '2021-12-27': '_0',
    '2021-01-10': '_0',
    '2021-01-31': '_0',
    '2022-03-07': '_0',
}

def gen_url(directory_date: dt, file_date: dt):
    year_month = directory_date.strftime('%Y-%m')  # Eg. 2022-03
    day_month_year = str(file_date.day)
    postfix = file_has_postfix.get(file_date.strftime('%Y-%m-%d'), '')
    base_url = ''

    # day_month_year
    if (file_date.year <= 2019) or \
        (file_date.year == 2022 and (file_date.month == 6 or file_date.month == 7)):
        day_month_year += file_date.strftime(' %B %Y')  # Eg. 3 June 2022
    else:
        day_month_year += file_date.strftime(' %b %Y')  # Eg. 3 Oct 2022
    
    # base url
    if file_date.year <= 2019:
        base_url = 'SGX Institutional and Retail fund flow weekly tracker '
    else:
        base_url = 'SGX Fund Flow Weekly Tracker '

    url = f'https://api2.sgx.com/sites/default/files/{year_month}/{base_url}(Week of {day_month_year}){postfix}.xlsx'
    
    return url

# %%
def slow_api_req():
    time.sleep(3 * random.random())

# %%
# fresh start the data directory
if os.path.exists(data_dir_url):
    shutil.rmtree(data_dir_url)

os.mkdir(data_dir_url)

# fetch data and preprocess the data
for date in trading_date_list:
    directory_date = date
    file_date = date - dt.timedelta(days=7)  # Refer to last week data

    n_days = 1

    while True:
        try:
            url = gen_url(directory_date, file_date)
            print(url)
            

            req = requests.get(url)
            assert req.status_code != 404

            excel_file = req.content

            inst_retail_buy_sell_df = parse_excel(excel_file)
            
            for df, filepath in zip(inst_retail_buy_sell_df, csv_file_list):
                write_csv(df, filepath, date)

            break
        except AssertionError:
            # if Monday is holiday, increase by T + 1 day
            print('### ERROR: ' + file_date.strftime('%Y-%m-%d'))
            file_date = file_date + dt.timedelta(days=1)
        
        n_days += 1

        # after 5 business day, terminate the call
        if n_days >= 5:
            break

        slow_api_req()
# Out:
# https://api2.sgx.com/sites/default/files/2019-01/SGX Institutional and Retail fund flow weekly tracker (Week of 31 December 2018).xlsx
# https://api2.sgx.com/sites/default/files/2019-01/SGX Institutional and Retail fund flow weekly tracker (Week of 7 January 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-01/SGX Institutional and Retail fund flow weekly tracker (Week of 14 January 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-01/SGX Institutional and Retail fund flow weekly tracker (Week of 21 January 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-02/SGX Institutional and Retail fund flow weekly tracker (Week of 28 January 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-02/SGX Institutional and Retail fund flow weekly tracker (Week of 4 February 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-02/SGX Institutional and Retail fund flow weekly tracker (Week of 11 February 2019)_3.xlsx
# https://api2.sgx.com/sites/default/files/2019-02/SGX Institutional and Retail fund flow weekly tracker (Week of 18 February 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-03/SGX Institutional and Retail fund flow weekly tracker (Week of 25 February 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-03/SGX Institutional and Retail fund flow weekly tracker (Week of 4 March 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-03/SGX Institutional and Retail fund flow weekly tracker (Week of 11 March 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-03/SGX Institutional and Retail fund flow weekly tracker (Week of 18 March 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-04/SGX Institutional and Retail fund flow weekly tracker (Week of 25 March 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-04/SGX Institutional and Retail fund flow weekly tracker (Week of 1 April 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-04/SGX Institutional and Retail fund flow weekly tracker (Week of 8 April 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-04/SGX Institutional and Retail fund flow weekly tracker (Week of 15 April 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-04/SGX Institutional and Retail fund flow weekly tracker (Week of 22 April 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-05/SGX Institutional and Retail fund flow weekly tracker (Week of 29 April 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-05/SGX Institutional and Retail fund flow weekly tracker (Week of 6 May 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-05/SGX Institutional and Retail fund flow weekly tracker (Week of 13 May 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-05/SGX Institutional and Retail fund flow weekly tracker (Week of 20 May 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-06/SGX Institutional and Retail fund flow weekly tracker (Week of 27 May 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-06/SGX Institutional and Retail fund flow weekly tracker (Week of 3 June 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-06/SGX Institutional and Retail fund flow weekly tracker (Week of 10 June 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-06/SGX Institutional and Retail fund flow weekly tracker (Week of 17 June 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-07/SGX Institutional and Retail fund flow weekly tracker (Week of 24 June 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-07/SGX Institutional and Retail fund flow weekly tracker (Week of 1 July 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-07/SGX Institutional and Retail fund flow weekly tracker (Week of 8 July 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-07/SGX Institutional and Retail fund flow weekly tracker (Week of 15 July 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-07/SGX Institutional and Retail fund flow weekly tracker (Week of 22 July 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-08/SGX Institutional and Retail fund flow weekly tracker (Week of 29 July 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-08/SGX Institutional and Retail fund flow weekly tracker (Week of 5 August 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-08/SGX Institutional and Retail fund flow weekly tracker (Week of 12 August 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-08/SGX Institutional and Retail fund flow weekly tracker (Week of 19 August 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-09/SGX Institutional and Retail fund flow weekly tracker (Week of 26 August 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-09/SGX Institutional and Retail fund flow weekly tracker (Week of 2 September 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-09/SGX Institutional and Retail fund flow weekly tracker (Week of 9 September 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-09/SGX Institutional and Retail fund flow weekly tracker (Week of 16 September 2019)_2.xlsx
# https://api2.sgx.com/sites/default/files/2019-09/SGX Institutional and Retail fund flow weekly tracker (Week of 23 September 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-10/SGX Institutional and Retail fund flow weekly tracker (Week of 30 September 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-10/SGX Institutional and Retail fund flow weekly tracker (Week of 7 October 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-10/SGX Institutional and Retail fund flow weekly tracker (Week of 14 October 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-10/SGX Institutional and Retail fund flow weekly tracker (Week of 21 October 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-11/SGX Institutional and Retail fund flow weekly tracker (Week of 28 October 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-11/SGX Institutional and Retail fund flow weekly tracker (Week of 4 November 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-11/SGX Institutional and Retail fund flow weekly tracker (Week of 11 November 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-11/SGX Institutional and Retail fund flow weekly tracker (Week of 18 November 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-12/SGX Institutional and Retail fund flow weekly tracker (Week of 25 November 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-12/SGX Institutional and Retail fund flow weekly tracker (Week of 2 December 2019).xlsx
# https://api2.sgx.com/sites/default/files/2019-12/SGX Institutional and Retail fund flow weekly tracker (Week of 9 December 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-12/SGX Institutional and Retail fund flow weekly tracker (Week of 16 December 2019)_0.xlsx
# https://api2.sgx.com/sites/default/files/2019-12/SGX Institutional and Retail fund flow weekly tracker (Week of 23 December 2019).xlsx
# https://api2.sgx.com/sites/default/files/2020-01/SGX Institutional and Retail fund flow weekly tracker (Week of 30 December 2019).xlsx
# https://api2.sgx.com/sites/default/files/2020-01/SGX Fund Flow Weekly Tracker (Week of 6 Jan 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-01/SGX Fund Flow Weekly Tracker (Week of 13 Jan 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-01/SGX Fund Flow Weekly Tracker (Week of 20 Jan 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-02/SGX Fund Flow Weekly Tracker (Week of 27 Jan 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-02/SGX Fund Flow Weekly Tracker (Week of 3 Feb 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-02/SGX Fund Flow Weekly Tracker (Week of 10 Feb 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-02/SGX Fund Flow Weekly Tracker (Week of 17 Feb 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-03/SGX Fund Flow Weekly Tracker (Week of 24 Feb 2020)_2.xlsx
# https://api2.sgx.com/sites/default/files/2020-03/SGX Fund Flow Weekly Tracker (Week of 2 Mar 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-03/SGX Fund Flow Weekly Tracker (Week of 9 Mar 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-03/SGX Fund Flow Weekly Tracker (Week of 16 Mar 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-03/SGX Fund Flow Weekly Tracker (Week of 23 Mar 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-04/SGX Fund Flow Weekly Tracker (Week of 30 Mar 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-04/SGX Fund Flow Weekly Tracker (Week of 6 Apr 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-04/SGX Fund Flow Weekly Tracker (Week of 13 Apr 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-04/SGX Fund Flow Weekly Tracker (Week of 20 Apr 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-05/SGX Fund Flow Weekly Tracker (Week of 27 Apr 2020)_0.xlsx
# https://api2.sgx.com/sites/default/files/2020-05/SGX Fund Flow Weekly Tracker (Week of 4 May 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-05/SGX Fund Flow Weekly Tracker (Week of 11 May 2020)_0.xlsx
# https://api2.sgx.com/sites/default/files/2020-05/SGX Fund Flow Weekly Tracker (Week of 18 May 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 25 May 2020).xlsx
# ### ERROR: 2020-05-25
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 26 May 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 1 Jun 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 8 Jun 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 15 Jun 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-06/SGX Fund Flow Weekly Tracker (Week of 22 Jun 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-07/SGX Fund Flow Weekly Tracker (Week of 29 Jun 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-07/SGX Fund Flow Weekly Tracker (Week of 6 Jul 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-07/SGX Fund Flow Weekly Tracker (Week of 13 Jul 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-07/SGX Fund Flow Weekly Tracker (Week of 20 Jul 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 27 Jul 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 3 Aug 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 10 Aug 2020).xlsx
# ### ERROR: 2020-08-10
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 11 Aug 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 17 Aug 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-08/SGX Fund Flow Weekly Tracker (Week of 24 Aug 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-09/SGX Fund Flow Weekly Tracker (Week of 31 Aug 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-09/SGX Fund Flow Weekly Tracker (Week of 7 Sep 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-09/SGX Fund Flow Weekly Tracker (Week of 14 Sep 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-09/SGX Fund Flow Weekly Tracker (Week of 21 Sep 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-10/SGX Fund Flow Weekly Tracker (Week of 28 Sep 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-10/SGX Fund Flow Weekly Tracker (Week of 5 Oct 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-10/SGX Fund Flow Weekly Tracker (Week of 12 Oct 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-10/SGX Fund Flow Weekly Tracker (Week of 19 Oct 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-11/SGX Fund Flow Weekly Tracker (Week of 26 Oct 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-11/SGX Fund Flow Weekly Tracker (Week of 2 Nov 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-11/SGX Fund Flow Weekly Tracker (Week of 9 Nov 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-11/SGX Fund Flow Weekly Tracker (Week of 16 Nov 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-11/SGX Fund Flow Weekly Tracker (Week of 23 Nov 2020)_0.xlsx
# https://api2.sgx.com/sites/default/files/2020-12/SGX Fund Flow Weekly Tracker (Week of 30 Nov 2020)_0.xlsx
# https://api2.sgx.com/sites/default/files/2020-12/SGX Fund Flow Weekly Tracker (Week of 7 Dec 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-12/SGX Fund Flow Weekly Tracker (Week of 14 Dec 2020).xlsx
# https://api2.sgx.com/sites/default/files/2020-12/SGX Fund Flow Weekly Tracker (Week of 21 Dec 2020).xlsx
# https://api2.sgx.com/sites/default/files/2021-01/SGX Fund Flow Weekly Tracker (Week of 28 Dec 2020).xlsx
# https://api2.sgx.com/sites/default/files/2021-01/SGX Fund Flow Weekly Tracker (Week of 4 Jan 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-01/SGX Fund Flow Weekly Tracker (Week of 11 Jan 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-01/SGX Fund Flow Weekly Tracker (Week of 18 Jan 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-02/SGX Fund Flow Weekly Tracker (Week of 25 Jan 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-02/SGX Fund Flow Weekly Tracker (Week of 1 Feb 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-02/SGX Fund Flow Weekly Tracker (Week of 8 Feb 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-02/SGX Fund Flow Weekly Tracker (Week of 15 Feb 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-03/SGX Fund Flow Weekly Tracker (Week of 22 Feb 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-03/SGX Fund Flow Weekly Tracker (Week of 1 Mar 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-03/SGX Fund Flow Weekly Tracker (Week of 8 Mar 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-03/SGX Fund Flow Weekly Tracker (Week of 15 Mar 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-03/SGX Fund Flow Weekly Tracker (Week of 22 Mar 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-04/SGX Fund Flow Weekly Tracker (Week of 29 Mar 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-04/SGX Fund Flow Weekly Tracker (Week of 5 Apr 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-04/SGX Fund Flow Weekly Tracker (Week of 12 Apr 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-04/SGX Fund Flow Weekly Tracker (Week of 19 Apr 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-05/SGX Fund Flow Weekly Tracker (Week of 26 Apr 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-05/SGX Fund Flow Weekly Tracker (Week of 3 May 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-05/SGX Fund Flow Weekly Tracker (Week of 10 May 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-05/SGX Fund Flow Weekly Tracker (Week of 17 May 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-05/SGX Fund Flow Weekly Tracker (Week of 24 May 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-06/SGX Fund Flow Weekly Tracker (Week of 31 May 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-06/SGX Fund Flow Weekly Tracker (Week of 7 Jun 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-06/SGX Fund Flow Weekly Tracker (Week of 14 Jun 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-06/SGX Fund Flow Weekly Tracker (Week of 21 Jun 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-07/SGX Fund Flow Weekly Tracker (Week of 28 Jun 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-07/SGX Fund Flow Weekly Tracker (Week of 5 Jul 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-07/SGX Fund Flow Weekly Tracker (Week of 12 Jul 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-07/SGX Fund Flow Weekly Tracker (Week of 19 Jul 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-08/SGX Fund Flow Weekly Tracker (Week of 26 Jul 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-08/SGX Fund Flow Weekly Tracker (Week of 2 Aug 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-08/SGX Fund Flow Weekly Tracker (Week of 9 Aug 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-08/SGX Fund Flow Weekly Tracker (Week of 16 Aug 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-08/SGX Fund Flow Weekly Tracker (Week of 23 Aug 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-09/SGX Fund Flow Weekly Tracker (Week of 30 Aug 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-09/SGX Fund Flow Weekly Tracker (Week of 6 Sep 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-09/SGX Fund Flow Weekly Tracker (Week of 13 Sep 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-09/SGX Fund Flow Weekly Tracker (Week of 20 Sep 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-10/SGX Fund Flow Weekly Tracker (Week of 27 Sep 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-10/SGX Fund Flow Weekly Tracker (Week of 4 Oct 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-10/SGX Fund Flow Weekly Tracker (Week of 11 Oct 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-10/SGX Fund Flow Weekly Tracker (Week of 18 Oct 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-11/SGX Fund Flow Weekly Tracker (Week of 25 Oct 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-11/SGX Fund Flow Weekly Tracker (Week of 1 Nov 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-11/SGX Fund Flow Weekly Tracker (Week of 8 Nov 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-11/SGX Fund Flow Weekly Tracker (Week of 15 Nov 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-11/SGX Fund Flow Weekly Tracker (Week of 22 Nov 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-12/SGX Fund Flow Weekly Tracker (Week of 29 Nov 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-12/SGX Fund Flow Weekly Tracker (Week of 6 Dec 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-12/SGX Fund Flow Weekly Tracker (Week of 13 Dec 2021).xlsx
# https://api2.sgx.com/sites/default/files/2021-12/SGX Fund Flow Weekly Tracker (Week of 20 Dec 2021).xlsx
# https://api2.sgx.com/sites/default/files/2022-01/SGX Fund Flow Weekly Tracker (Week of 27 Dec 2021)_0.xlsx
# https://api2.sgx.com/sites/default/files/2022-01/SGX Fund Flow Weekly Tracker (Week of 3 Jan 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-01/SGX Fund Flow Weekly Tracker (Week of 10 Jan 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-01/SGX Fund Flow Weekly Tracker (Week of 17 Jan 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-01/SGX Fund Flow Weekly Tracker (Week of 24 Jan 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-02/SGX Fund Flow Weekly Tracker (Week of 31 Jan 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-02/SGX Fund Flow Weekly Tracker (Week of 7 Feb 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-02/SGX Fund Flow Weekly Tracker (Week of 14 Feb 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-02/SGX Fund Flow Weekly Tracker (Week of 21 Feb 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-03/SGX Fund Flow Weekly Tracker (Week of 28 Feb 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-03/SGX Fund Flow Weekly Tracker (Week of 7 Mar 2022)_0.xlsx
# https://api2.sgx.com/sites/default/files/2022-03/SGX Fund Flow Weekly Tracker (Week of 14 Mar 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-03/SGX Fund Flow Weekly Tracker (Week of 21 Mar 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-04/SGX Fund Flow Weekly Tracker (Week of 28 Mar 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-04/SGX Fund Flow Weekly Tracker (Week of 4 Apr 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-04/SGX Fund Flow Weekly Tracker (Week of 11 Apr 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-04/SGX Fund Flow Weekly Tracker (Week of 18 Apr 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-05/SGX Fund Flow Weekly Tracker (Week of 25 Apr 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-05/SGX Fund Flow Weekly Tracker (Week of 2 May 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-05/SGX Fund Flow Weekly Tracker (Week of 9 May 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-05/SGX Fund Flow Weekly Tracker (Week of 16 May 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-05/SGX Fund Flow Weekly Tracker (Week of 23 May 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-06/SGX Fund Flow Weekly Tracker (Week of 30 May 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-06/SGX Fund Flow Weekly Tracker (Week of 6 June 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-06/SGX Fund Flow Weekly Tracker (Week of 13 June 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-06/SGX Fund Flow Weekly Tracker (Week of 20 June 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-07/SGX Fund Flow Weekly Tracker (Week of 27 June 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-07/SGX Fund Flow Weekly Tracker (Week of 4 July 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-07/SGX Fund Flow Weekly Tracker (Week of 11 July 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-07/SGX Fund Flow Weekly Tracker (Week of 18 July 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-08/SGX Fund Flow Weekly Tracker (Week of 25 July 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-08/SGX Fund Flow Weekly Tracker (Week of 1 Aug 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-08/SGX Fund Flow Weekly Tracker (Week of 8 Aug 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-08/SGX Fund Flow Weekly Tracker (Week of 15 Aug 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-08/SGX Fund Flow Weekly Tracker (Week of 22 Aug 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-09/SGX Fund Flow Weekly Tracker (Week of 29 Aug 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-09/SGX Fund Flow Weekly Tracker (Week of 5 Sep 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-09/SGX Fund Flow Weekly Tracker (Week of 12 Sep 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-09/SGX Fund Flow Weekly Tracker (Week of 19 Sep 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-10/SGX Fund Flow Weekly Tracker (Week of 26 Sep 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-10/SGX Fund Flow Weekly Tracker (Week of 3 Oct 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-10/SGX Fund Flow Weekly Tracker (Week of 10 Oct 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-10/SGX Fund Flow Weekly Tracker (Week of 17 Oct 2022).xlsx
# https://api2.sgx.com/sites/default/files/2022-10/SGX Fund Flow Weekly Tracker (Week of 24 Oct 2022).xlsx

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Update ticker

# %% [markdown]
# For company that has update their ticker, we need to update their old ticker to the latest ticker

# %%
constants.updated_ticker
# Out:
# {'41A.SI': '8K7.SI',
#  'O32.SI': 'VC2.SI',
#  'A68U.SI': 'HMN.SI',
#  'CNNU.SI': 'CWBU.SI',
#  'CH8.SI': 'QES.SI'}

# %%
updated_ticker = constants.updated_ticker

for url in csv_file_list:
    df = pd.read_csv(url)
    df['stock code'] = df['stock code'].apply(lambda ticker: updated_ticker[ticker] if ticker in updated_ticker.keys() else ticker)

    df.to_csv(url, index=False)

# %% [markdown]
# ## Remove delisted stock

# %%
def get_stock_ticker(url):
    df = pd.read_csv(url)
    tickers = df['stock code'].unique().tolist()

    return tickers

# %%
def remove_delisted_stock(url, delieted_ticker):
    df = pd.read_csv(url)
    delisted_stock_bool = df['stock code'].isin(delieted_ticker)

    delisted_stock_bool = df['stock code'].isin(delieted_ticker)
    df = df[~delisted_stock_bool]

    return df

# %%
# Get all ticker exist in data
tickers = []

for url in csv_file_list:
    tickers.extend(get_stock_ticker(url))

tickers = set(tickers)

# Find delisted stock
delisted_tickers = []

for ticker in tickers:
    hist = yf.Ticker(ticker).history()

    if len(hist) == 0:
        delisted_tickers.append(ticker)

# Filter and update the csv
for url in csv_file_list:
    df = remove_delisted_stock(url, delisted_tickers)
    df.to_csv(url, index=False)
# Out:
# T39.SI: No data found, symbol may be delisted
# ADQU.SI: No data found, symbol may be delisted
# F25U.SI: No data found, symbol may be delisted
# B16.SI: No data found, symbol may be delisted
# J37.SI: No data found, symbol may be delisted
# 5ME.SI: No data found, symbol may be delisted
# RF1U.SI: No data found, symbol may be delisted
# PGU.SI: No data found, symbol may be delisted
# 588.SI: No data found, symbol may be delisted
# 5H0.SI: No data found, symbol may be delisted
# C61U.SI: No data found, symbol may be delisted
# VL6.SI: No data found, symbol may be delisted
# K2LU.SI: No data found, symbol may be delisted
# C31.SI: No data found, symbol may be delisted
# CTN.SI: No data found, symbol may be delisted
# U04.SI: No data found, symbol may be delisted
# BQO.SI: No data found, symbol may be delisted
# AYL.SI: No data found, symbol may be delisted
# CEE.SI: No data found, symbol may be delisted
# K11.SI: No data found, symbol may be delisted
# ND8U.SI: No data found, symbol may be delisted
# B2F.SI: No data found, symbol may be delisted
# 40S.SI: No data found, symbol may be delisted
# Q1P.SI: No data found, symbol may be delisted
# VTA.SI: No data found, symbol may be delisted
# BOL.SI: No data found, symbol may be delisted
# RW0U.SI: No data found, symbol may be delisted
# H17.SI: No data found, symbol may be delisted
# 5UZ.SI: No data found, symbol may be delisted

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a59e5772-0ffb-4811-b384-2b5a9f52032a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
